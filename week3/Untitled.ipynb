# %%
import matplotlib.pyplot as plt

# %%
x = [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008]
data = [5, 2, 3, 6, 5, 2, 3, 6]

# %%
x
# Out:
# [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008]

# %%
data
# Out:
# [5, 2, 3, 6, 5, 2, 3, 6]

# %%
plt.plot(x, data)

plt.show()
