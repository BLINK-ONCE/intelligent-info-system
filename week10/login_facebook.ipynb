# %%
from selenium import webdriver

driver = webdriver.Chrome("../chromedriver")
# Out:
# /var/folders/j2/9jlbt4m54g7_xxbsdb4wf9_r0000gn/T/ipykernel_3041/1126923817.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("../chromedriver")

# %%
driver.get('https://ko-kr.facebook.com/')

# %%
driver.find_element('id', 'email').send_keys('id or email')

# %%
driver.find_element('id', 'pass').send_keys('password')

# %%
login_btn = '/html/body/div[1]/div[1]/div[1]/div/div/div/div[2]/div/div[1]/form/div[2]/button'
driver.find_element('xpath', login_btn).click()

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-11-07%2011.30.44.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-11-07%2011.30.44.png)
